# %% [markdown]
# <h3>Happy Customers</h3>

# %% [markdown]
# <h4>Notebook 5</h4>

# %% [markdown]
# Re-evaluating my feature selection process with other methods

# %%
import pandas as pd
import numpy as np
